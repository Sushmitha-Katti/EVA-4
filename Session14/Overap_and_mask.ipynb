# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmitha-Katti/EVA-4/blob/master/Session14/Overap_and_mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
from PIL import Image
import random
import copy
import PIL

# %%
path = '/content/gdrive/My Drive/Mask_Rcnn/'
start = 24001 # -----------------------You should choose your numbers----------------------------------
black = np.zeros((224,224,3))

for i in range(31,41): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}Background/bg{str(i)}.jpg')

    for j in  range(1,21): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}Foreground/fg{str(j)}.png')
      mask = Image.open(f'{path}Mask/mask{str(j)}.png')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 80)
        r2 = random.randint(1, 80)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='RGB')
        black_img2 = Image.fromarray(black,mode='RGB')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        

        bg1.paste(fg1, (r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"{path}Fg-Bg/fg-bg{str(start)}.jpg")#------------Create Different folder-------------
        black_img1.save(f"{path}Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg") #-------------Create Different Path folder----

        start+=1

        bg2.save(f"{path}Fg-Bg/fg-bg{str(start)}.jpg")#------------Create Different folder---------------
        black_img2.save(f"{path}Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg")#------------Create Different folder-----------

        start+=1
        print(start)
# Out:
# 24003
# 24005
# 24007
# 24009
# 24011
# 24013
# 24015
# 24017
# 24019
# 24021
# 24023
# 24025
# 24027
# 24029
# 24031
# 24033
# 24035
# 24037
# 24039
# 24041
# 24043
# 24045
# 24047
# 24049
# 24051
# 24053
# 24055
# 24057
# 24059
# 24061
# 24063
# 24065
# 24067
# 24069
# 24071
# 24073
# 24075
# 24077
# 24079
# 24081
# 24083
# 24085
# 24087
# 24089
# 24091
# 24093
# 24095
# 24097
# 24099
# 24101
# 24103
# 24105
# 24107
# 24109
# 24111
# 24113
# 24115
# 24117
# 24119
# 24121
# 24123
# 24125
# 24127
# 24129
# 24131
# 24133
# 24135
# 24137
# 24139
# 24141
# 24143
# 24145
# 24147
# 24149
# 24151
# 24153
# 24155
# 24157
# 24159
# 24161
# 24163
# 24165
# 24167
# 24169
# 24171
# 24173
# 24175
# 24177
# 24179
# 24181
# 24183
# 24185
# 24187
# 24189
# 24191
# 24193
# 24195
# 24197
# 24199
# 24201
# 24203
# 24205
# 24207
# 24209
# 24211
# 24213
# 24215
# 24217
# 24219
# 24221
# 24223
# 24225
# 24227
# 24229
# 24231
# 24233
# 24235
# 24237
# 24239
# 24241
# 24243
# 24245
# 24247
# 24249
# 24251
# ...
