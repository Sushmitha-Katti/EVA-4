# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmitha-Katti/EVA-4/blob/master/Session14/Overap_and_mask_V3(with_reduce_data_storage).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import numpy as np
from PIL import Image
import random
import copy
import PIL

# %%
# !mkdir Overlay1

# %%
# %cd Overlay1
# !mkdir Fg-Bg
# !mkdir Fg-Bg-Mask
# Out:
# /content/Overlay1

# %%
# %cd ..
# Out:
# /content

# %%
path = '/content/gdrive/My Drive/Mask_Rcnn/'
start =1 # -----------------------You should choose your numbers----------------------------------
black = np.zeros((224,224))



for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}living_room_224_224/bg{str(i)}.jpg')

    for j in  range(1,21): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}Sushmitha/Foreground/fg{str(j)}.png')
      mask = Image.open(f'{path}Sushmitha/Mask/mask{str(j)}.jpg').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        

        bg1.paste(fg1, (r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/Overlay1/Fg-Bg/fg-bg{str(start)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/Overlay1/Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start+=1

        bg2.save(f"/content/Overlay1/Fg-Bg/fg-bg{str(start)}.jpg", optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/Overlay1/Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg", optimize=True, quality=30)#------------Create Different folder-----------

        start+=1
        print(start)
# Out:
# Streaming output truncated to the last 5000 lines.
# 22707
# 22709
# 22711
# 22713
# 22715
# 22717
# 22719
# 22721
# 22723
# 22725
# 22727
# 22729
# 22731
# 22733
# 22735
# 22737
# 22739
# 22741
# 22743
# 22745
# 22747
# 22749
# 22751
# 22753
# 22755
# 22757
# 22759
# 22761
# 22763
# 22765
# 22767
# 22769
# 22771
# 22773
# 22775
# 22777
# 22779
# 22781
# 22783
# 22785
# 22787
# 22789
# 22791
# 22793
# 22795
# 22797
# 22799
# 22801
# 22803
# 22805
# 22807
# 22809
# 22811
# 22813
# 22815
# 22817
# 22819
# 22821
# 22823
# 22825
# 22827
# 22829
# 22831
# 22833
# 22835
# 22837
# 22839
# 22841
# 22843
# 22845
# 22847
# 22849
# 22851
# 22853
# 22855
# 22857
# 22859
# 22861
# 22863
# 22865
# 22867
# 22869
# 22871
# 22873
# 22875
# 22877
# 22879
# 22881
# 22883
# 22885
# 22887
# 22889
# 22891
# 22893
# 22895
# 22897
# 22899
# 22901
# 22903
# 22905
# 22907
# 22909
# 22911
# 22913
# 22915
# 22917
# 22919
# 22921
# 22923
# 22925
# 22927
# 22929
# 22931
# 22933
# 22935
# 22937
# 22939
# 22941
# ...

# %%
# !pwd
# Out:
# /content

# %%
#Export Zip file
from zipfile import ZipFile 
import zipfile
import os 
  
def get_all_file_paths(directory): 
  
    # initializing empty file paths list 
    file_paths = [] 
  
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): 
        for filename in files: 
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath) 
  
    # returning all file paths 
    return file_paths         
  
def main(): 
    # path to folder which needs to be zipped 
    directory = 'Overlay'
  
    # calling function to get all file paths in the directory 
    file_paths = get_all_file_paths(directory) 
  
    # printing the list of all files to be zipped 
    print('Following files will be zipped:') 
    for file_name in file_paths: 
        print(file_name) 
  
    # writing files to a zipfile 
    with ZipFile('/content/gdrive/My Drive/Mask_Rcnn/Sushmitha/dataset_1to80k','a', compression = zipfile.ZIP_DEFLATED) as zip: 
        # writing each file one by one 
        for file in file_paths: 
            zip.write(file) 
  
    print('All files zipped successfully!')         
  
  

main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Overlay/Fg-Bg-Mask/fg-bg-mask62585.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask49291.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask71454.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask41307.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask33422.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask28467.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask66790.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask67204.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask78795.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask19324.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask25980.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask72297.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask25710.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask73623.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask64844.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask43383.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask29469.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask25724.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask41934.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask11538.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask7226.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask35309.jpg
# Overlay/Fg-Bg-Mask/fg-bg-mask38480.jpg
# ...

# %%
# To extract a  file, this is for depth images. After zipping. Only to read images

#To import zip file
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "/content/gdrive/My Drive/Mask_Rcnn/Sushmitha/dataset_1to80k"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
# !ls
# Out:
# gdrive	Overlay  sample_data

# %%
# !ls Overlay/Fg-Bg |wc - l
# Out:
#   80000   80000 1188894 -
# wc: l: No such file or directory
#   80000   80000 1188894 total

# %%
# !ls Overlay/Fg-Bg-Mask | wc -l
# Out:
# 80000

# %%
from IPython.display import Image as IMAGE
from PIL import Image,ImageOps
import cv2
from google.colab.patches import cv2_imshow
src = Image.open("Overlay/Fg-Bg/fg-bg80000.jpg")
# img = cv2_imshow(src[:,:,3])
src
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FECE55C1710>

# %%
import io
with ZipFile("Hi/test.zip", 'r') as zip: 
  #zip.printdir()
  b = zip.read('Overlay/Fg-Bg/fg-bg80000.jpg')
  #image_data = archive.read("image.png")
  print(b)
  fh = io.BytesIO(b)
  img = Image.open(fh)
  img = img.resize((672,672)) 
  img.save("/content/1.jpg")

  
# # img = cv2_imshow(src[:,:,3])
# src
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x1b\x12\x14\x17\x14\x11\x1b\x17\x16\x17\x1e\x1c\x1b (B+(%%(Q:=0B`Ued_U][jx\x99\x81jq\x90s[]\x85\xb5\x86\x90\x9e\xa3\xab\xad\xabg\x80\xbc\xc9\xba\xa6\xc7\x99\xa8\xab\xa4\xff\xdb\x00C\x01\x1c\x1e\x1e(#(N++N\xa4n]n\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xa4\xff\xc0\x00\x11\x08\x00\xe0\x00\xe0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94
# ...

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=672x672 at 0x7FECDE9AEC50>

# %%
# !git clone https://github.com/Sushmitha-Katti/DepthModel
# Out:
# Cloning into 'DepthModel'...
# remote: Enumerating objects: 245, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 245 (delta 124), reused 244 (delta 123), pack-reused 0
# Receiving objects: 100% (245/245), 11.81 MiB | 32.60 MiB/s, done.
# Resolving deltas: 100% (124/124), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DepthModel/nyu.h5
# Out:
# --2020-05-05 05:34:59--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.100.115
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.100.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DepthModel/nyu.h5’
#
# ./DepthModel/nyu.h5 100%[===================>] 164.89M  22.3MB/s    in 8.3s
#
# 2020-05-05 05:35:08 (19.8 MB/s) - ‘./DepthModel/nyu.h5’ saved [172897376/172897376]

# %%
# !cd DepthModel; python test.py --input '/content/1.jpg' --end 2
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (1) images of size (672, 672, 3).
# (336, 336, 3)
# (336, 336)
# (336, 336)
# 2
# done

# %%
img = Image.open("/content/DepthModel/test1.jpg")

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FECD5703898>
