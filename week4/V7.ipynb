# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmitha-Katti/EVA-4/blob/master/week4/V7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
class Net(nn.Module):
    def __init__(self):
            super(Net, self).__init__()
            self.conv1 = nn.Sequential(                      #26
            nn.Conv2d(1, 16, 3, bias = False),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.BatchNorm2d(16),
            nn.Conv2d(16, 16, 3, bias = False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1),
            nn.Conv2d(16, 16, 3, bias = False ),        #10
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(16, 16, 3, bias = False), #8
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1),
            nn.Conv2d(16, 16, 3, bias = False ), #6
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1),
            nn.Conv2d(16, 16, 3, bias = False ), #4
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1),
            nn.Conv2d(16, 16, 3,  bias = False ), #2
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1),
            nn.Conv2d(16,10,3)
            
        )
            self.conv2 = nn.Sequential(                  #24
            nn.Conv2d(16, 16, 3, bias = False),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1)
        )
            self.conv3 = nn.Sequential(               #12
           
            nn.Conv2d(16, 16, 3, bias = False ),        #10
            nn.ReLU(),
            #nn.BatchNorm2d(16),
            #nn.Dropout(0.1)
            
        )
            self.conv4 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Conv2d(16, 16, 3, bias = False), #8
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1)
        )
            self.conv5 = nn.Sequential(
            #nn.MaxPool2d(2, 2),          
            nn.Conv2d(16, 16, 3, bias = False ), #6
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.Dropout(0.1)
        )
            self.conv6 = nn.Sequential(
            
            nn.Conv2d(16, 32, 3, bias = False ), #4
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Dropout(0.1)
        )
            self.conv7 = nn.Sequential(
            nn.Conv2d(32, 32, 3,  bias = False ), #2
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Dropout(0.1)
        )
            
       
        
            self.fc = nn.Sequential(
            nn.Conv2d(32,10,3)
        )
                


    def forward(self, x):
        x = self.conv1(x)
        #x = self.conv2(x)
        #x = self.conv3(x)
        #x = self.conv4(x)
        #x = self.conv5(x)
        #x = self.conv6(x)
       # x = self.conv7(x)
        #x = self.fc(x)
        x = x.view(x.size(0), -1)
        
        x = F.log_softmax(x, dim=1)
        return x

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
summary(model, input_size=(1, 28, 28))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             144
#               ReLU-2           [-1, 16, 26, 26]               0
#            Dropout-3           [-1, 16, 26, 26]               0
#        BatchNorm2d-4           [-1, 16, 26, 26]              32
#             Conv2d-5           [-1, 16, 24, 24]           2,304
#               ReLU-6           [-1, 16, 24, 24]               0
#        BatchNorm2d-7           [-1, 16, 24, 24]              32
#            Dropout-8           [-1, 16, 24, 24]               0
#             Conv2d-9           [-1, 16, 22, 22]           2,304
#              ReLU-10           [-1, 16, 22, 22]               0
#       BatchNorm2d-11           [-1, 16, 22, 22]              32
#           Dropout-12           [-1, 16, 22, 22]               0
#         MaxPool2d-13           [-1, 16, 11, 11]               0
#            Conv2d-14             [-1, 16, 9, 9]           2,304
#              ReLU-15             [-1, 16, 9, 9]               0
#       BatchNorm2d-16             [-1, 16, 9, 9]              32
#           Dropout-17             [-1, 16, 9, 9]               0
#            Conv2d-18             [-1, 16, 7, 7]           2,304
#              ReLU-19             [-1, 16, 7, 7]               0
#       BatchNorm2d-20             [-1, 16, 7, 7]              32
#           Dropout-21             [-1, 16, 7, 7]               0
#            Conv2d-22             [-1, 16, 5, 5]           2,304
#              ReLU-23             [-1, 16, 5, 5]               0
#       BatchNorm2d-24             [-1, 16, 5, 5]              32
#           Dropout-25             [-1, 16, 5, 5]               0
#            Conv2d-26             [-1, 16, 3, 3]           2,304
#              ReLU-27             [-1, 16, 3, 3]               0
#       BatchNorm2d-28             [-1, 16, 3, 3]              32
#           Dropout-29             [-1, 16, 3, 3]               0
#            Conv2d-30             [-1, 10, 1, 1]           1,450
# ================================================================
# Total params: 15,642
# Trainable params: 15,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.94
# Params size (MB): 0.06
# Estimated Total Size (MB): 1.01
# ----------------------------------------------------------------

# %%
torch.manual_seed(1)
batch_size = 128

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
from tqdm import tqdm
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    pbar = tqdm(train_loader)
    for batch_idx, (data, target) in enumerate(pbar):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        pbar.set_description(desc= f'epoch = {epoch} loss={loss.item()} batch_id={batch_idx}')


def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

for epoch in range(1, 20):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# epoch = 1 loss=0.23314636945724487 batch_id=468: 100%|██████████| 469/469 [00:12<00:00, 37.04it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0660, Accuracy: 9799/10000 (97.99%)
# epoch = 2 loss=0.061943504959344864 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 39.10it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0431, Accuracy: 9877/10000 (98.77%)
# epoch = 3 loss=0.028404168784618378 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 40.29it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0340, Accuracy: 9888/10000 (98.88%)
# epoch = 4 loss=0.13044804334640503 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 41.09it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0300, Accuracy: 9906/10000 (99.06%)
# epoch = 5 loss=0.011949852108955383 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 40.29it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0269, Accuracy: 9910/10000 (99.10%)
# epoch = 6 loss=0.0032805700320750475 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 39.50it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0288, Accuracy: 9906/10000 (99.06%)
# epoch = 7 loss=0.009208639152348042 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 42.69it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0289, Accuracy: 9912/10000 (99.12%)
# epoch = 8 loss=0.04440201446413994 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 40.31it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0257, Accuracy: 9918/10000 (99.18%)
# epoch = 9 loss=0.013667826540768147 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 41.91it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0273, Accuracy: 9910/10000 (99.10%)
# epoch = 10 loss=0.02136891521513462 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 39.21it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0271, Accuracy: 9919/10000 (99.19%)
# epoch = 11 loss=0.004716192837804556 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 39.31it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0232, Accuracy: 9925/10000 (99.25%)
# epoch = 12 loss=0.01485203206539154 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 42.13it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0219, Accuracy: 9934/10000 (99.34%)
# epoch = 13 loss=0.033516813069581985 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 41.20it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0237, Accuracy: 9927/10000 (99.27%)
# epoch = 14 loss=0.04066823422908783 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 40.36it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0282, Accuracy: 9917/10000 (99.17%)
# epoch = 15 loss=0.025138378143310547 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 42.70it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0237, Accuracy: 9929/10000 (99.29%)
# epoch = 16 loss=0.003951499704271555 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 42.98it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0202, Accuracy: 9933/10000 (99.33%)
# epoch = 17 loss=0.06425892561674118 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 41.01it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0225, Accuracy: 9930/10000 (99.30%)
# epoch = 18 loss=0.008397062309086323 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 39.64it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0205, Accuracy: 9933/10000 (99.33%)
# epoch = 19 loss=0.010800063610076904 batch_id=468: 100%|██████████| 469/469 [00:11<00:00, 39.80it/s]
# Test set: Average loss: 0.0172, Accuracy: 9949/10000 (99.49%)
